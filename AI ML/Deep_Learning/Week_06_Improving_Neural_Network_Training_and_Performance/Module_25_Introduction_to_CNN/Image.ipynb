# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open('/content/flower.jpg')
plt.imshow(image)
# plt.axis('off')
print(type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=526x514>

# %%
import numpy as np
image_array = np.array(image)
print(image_array)
# Out:
# [[[ 86 130 203]
#   [ 86 130 203]
#   [ 86 130 203]
#   ...
#   [ 55  46  29]
#   [ 55  46  29]
#   [ 55  46  29]]
#
#  [[ 86 130 203]
#   [ 86 130 203]
#   [ 86 130 203]
#   ...
#   [ 55  46  29]
#   [ 55  46  29]
#   [ 55  46  29]]
#
#  [[ 87 131 204]
#   [ 87 131 204]
#   [ 87 131 204]
#   ...
#   [ 55  46  29]
#   [ 55  46  29]
#   [ 55  46  29]]
#
#  ...
#
#  [[ 63  90   9]
#   [ 64  91  10]
#   [ 66  93  12]
#   ...
#   [ 69  71  83]
#   [ 69  71  83]
#   [ 69  71  83]]
#
#  [[ 75 104  24]
#   [ 75 104  24]
#   [ 76 104  27]
#   ...
#   [ 68  70  82]
#   [ 68  70  82]
#   [ 68  70  82]]
#
#  [[ 75 103  26]
#   [ 75 103  26]
#   [ 76 104  29]
#   ...
#   [ 68  70  82]
#   [ 68  70  82]
#   [ 68  70  82]]]

# %%
# Convert back to image
new_image = Image.fromarray(image_array)
# show image
new_image.show()
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=526x514>

# %% [markdown]
# ### Module Resource:-
#
# + https://drive.google.com/file/d/1li1ZY-gkHBVwHVnKTsaCmXv9y3w2-Jws/view
#
# + https://drive.google.com/file/d/1hO47CN4XCdxr7RaOut-kcbImQdeP5Oy1/view
#
# + https://drive.google.com/file/d/11s2vbrIfJNM_HppM-_2eato2yRJTWseM/view

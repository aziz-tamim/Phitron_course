# %%
phone_number = 456249
print(phone_number)
# Out:
# 456249

# %%
name = "Phitron"
print(name)
# Out:
# Phitron

# %%
age = 20
height = 5.6
name = "Tamim"
is_passed = True

print(type(age), type(height), type(name), type(is_passed))
age = 20.5
print(type(age))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# <class 'float'>

# %% [markdown]
# Taking Input in Python

# %%
name = input("What is your name? ")
print(name)
# Out:
# Tamim

# %%
age = input("Age ?")
print(age, type(age))
# Out:
# 20 <class 'str'>

# %%
age = input("Age ?") # string hisabe input nise
age = int(age) # string k amra int a convert korlam
print(age, type(age))
# Out:
# 50 <class 'int'>

# %%
height = input("Height ?")
print(height, type(height))
# Out:
# 8.5 <class 'str'>

# %%
height = float(input("Height ?"))

print(height, type(height))
height = height + 0.5
print(height)
# Out:
# 5.5 <class 'float'>
# 6.0

# %% [markdown]
# ## Q. Digits

# %%
t = int(input())
for i in range(t):
    number = int(input())
    if number == 0:
        print(0)
        continue
    while number > 0:
        print(number %10, end=" ")
        number //= 10
    print()
# Out:
# 0 0 2 1
# 2 1 2 3
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 t = int(input())
#       2 for i in range(t):
# ----> 3     number = int(input())
#       4     if number == 0:
#       5         print(0)
#
# ValueError: invalid literal for int() with base 10: ''

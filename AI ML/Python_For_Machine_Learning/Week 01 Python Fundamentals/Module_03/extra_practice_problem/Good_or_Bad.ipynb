# %% [markdown]
# ###### problem link - https://codeforces.com/group/MWSDmqGsZm/contest/219856/problem/H

# %%
n = int(input())

for i in range(n):
    inp = input()
    if "010" in inp:
        print("Good")
    elif "101" in inp:
        print("Good")
    else:
        print("Bad")
# Out:
# Bad
# Good

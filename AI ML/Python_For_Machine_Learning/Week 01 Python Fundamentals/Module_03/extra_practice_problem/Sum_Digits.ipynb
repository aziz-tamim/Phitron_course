# %% [markdown]
# ###### Problem link - https://codeforces.com/group/MWSDmqGsZm/contest/219774/problem/K

# %%
n = int(input())
arr = input()
sum = 0
for i in arr:
    sum += int(i)

print(sum)
# Out:
# 12

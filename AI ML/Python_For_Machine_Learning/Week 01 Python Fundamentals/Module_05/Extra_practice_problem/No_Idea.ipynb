# %% [markdown]
# ###### problem link - https://www.hackerrank.com/challenges/no-idea/

# %%
n,m = input().split()
n = int(n)
m = int(m)
arr = list(map(int, input().split()))

x = set(map(int,input().split()))
y = set(map(int, input().split()))

hp = 0
for i in arr:
    if i in x:
        hp +=1
    elif i in y:
        hp -= 1
print(hp)
# Out:
#  3 2
#  1 5 3
#  3 1
#  5 7
# 1

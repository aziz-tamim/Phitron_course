# %%
inp = int(input())
cnt1= 0; cnt2 = 0
for i in range(inp):
    vote = input()
    if vote == "YES":
        cnt1 += 1
    else:
        cnt2 += 1
if(cnt1>=cnt2):
    print("ACCEPT")
else:
    print("REJECT")

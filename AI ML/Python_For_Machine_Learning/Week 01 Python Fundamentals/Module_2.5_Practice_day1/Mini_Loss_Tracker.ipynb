# %%
n = int(input())

val = float(input())
all = 0.0
for i in range(n):
    loss = float(input())
    all += loss
overall = all/n
if overall <= val:
    print("PASS")
else:
    print("RETRY")
# Out:
# PASS

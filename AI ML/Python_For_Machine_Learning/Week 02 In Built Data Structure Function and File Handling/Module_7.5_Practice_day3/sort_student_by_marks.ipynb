# %% [markdown]
# ### Problem 2: Sort Students by Marks (Tuple + Dictionary)
# ##### Problem:
# ###### You are given a list of tuples — each containing a student’s name and mark.
# ###### Sort them in descending order of marks and print the top 3 scorers.
# Example Input:
# ###### students = [("Rafi", 89), ("Sumi", 95), ("Hasan", 90), ("Nila", 75), ("Anik", 98)]
#
# ###### Expected Output:
# ###### Top 3 students:
# ###### Anik - 98
# ###### Sumi - 95
# ###### Hasan - 90

# %%
students = [("Rafi", 89), ("Sumi", 95), ("Hasan", 90), ("Nila", 75), ("Anik", 98)]

marks_sort = sorted(students, key=lambda x: x[1], reverse=True)

top_3_student = marks_sort[:3]

print("Top 3 students:")
for name, marks in top_3_student:
    print(f"{name} - {marks}")
# Out:
# Top 3 students:
# Anik - 98
# Sumi - 95
# Hasan - 90

# %% [markdown]
# #### Create a Pandas Series from the list [10, 20, 30, 40, 50]. Print the Series, its index, and data type. Then create a DataFrame with columns "Name", "Age", and "City" containing at least 4 rows of data.

# %%
import pandas as pd 

series = pd.Series([10, 20, 30, 40, 50])
print(series)
print(series.index)
print(series.dtype)

data = [
    {'Name': 'Tamim', 'Age': 20, 'City': 'Noakhali'},
    {'Name': 'Shajid', 'Age': 21, 'City': 'Feni'},
    {'Name': 'Emon', 'Age': 22, 'City': 'Miroshorai'},
    {'Name': 'Mannan', 'Age': 23, 'City': 'Noakhali'}
]
df = pd.DataFrame(data)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# RangeIndex(start=0, stop=5, step=1)
# int64
#      Name  Age        City
# 0   Tamim   20    Noakhali
# 1  Shajid   21        Feni
# 2    Emon   22  Miroshorai
# 3  Mannan   23    Noakhali

# %% [markdown]
# ##### Using any DataFrame, write code to print the number of rows and columns, column data types (.dtypes), and summary statistics (.describe()).

# %%
data2 = [
    {"Name": "Abdu Aziz", "Roll": 879954, "department": "CST"},
    {"Name": "Mannan", "Roll": 879960, "department": "Civil"},
    {"Name": "Shajidul Islam", "Roll": 879929, "department": "Electrical"},
    {"Name": "Emon Golder", "Roll": 879951, "department": "Articture"}
]
df = pd.DataFrame(data2)
print(df.shape)
print(df.dtypes)
print(df.describe())
# Out:
# (4, 3)
# Name          object
# Roll           int64
# department    object
# dtype: object
#                 Roll
# count       4.000000
# mean   879948.500000
# std        13.527749
# min    879929.000000
# 25%    879945.500000
# 50%    879952.500000
# 75%    879955.500000
# max    879960.000000

# %% [markdown]
# #### Create a DataFrame using the dictionary below:
#
# ###### data = {
# ######    'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
# ######    'Price': [10, 50, 5, 7],
# ######    'Quantity': [100, 60, 200, 150]
# ###### }
# ###### Print .columns, .index. Access a single column and one full row.

# %%
data3 = {
    'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
    'Price': [10,50,5,7],
    'Quantity':[100,60,200,150]
}

df = pd.DataFrame(data3)
print(df.columns)
print(df.index)
print(df['Price'])
print(df.loc[0])
# Out:
# Index(['Product', 'Price', 'Quantity'], dtype='object')
# RangeIndex(start=0, stop=4, step=1)
# 0    10
# 1    50
# 2     5
# 3     7
# Name: Price, dtype: int64
# Product     Pen
# Price        10
# Quantity    100
# Name: 0, dtype: object

# %% [markdown]
# ##### 4. Using .loc[] and .iloc[], show the first row, the second column, and a 2×2 block    from the middle of your DataFrame.

# %%
data4 = {
    'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
    'Price': [10,50,5,7],
    'Quantity':[100,60,200,150]
}

df = pd.DataFrame(data4)
print(df.iloc[0])
print(df.iloc[:,1])

print(df.iloc[1:3, 0:2])
# Out:
# Product     Pen
# Price        10
# Quantity    100
# Name: 0, dtype: object
# 0    10
# 1    50
# 2     5
# 3     7
# Name: Price, dtype: int64
#   Product  Price
# 1    Book     50
# 2  Eraser      5

# %% [markdown]
# ##### 5. Create a 4×3 DataFrame of student names and marks. Drop one column using .drop(), drop one row by index

# %%
data5 = {
    'Name': ['Tamim', 'Shajid', 'Mannan', 'Emon'],
    'DSA Marks': [50, 65, 60, 85],
    'Python Marks': [86, 92, 48, 75],
    'Java Marks': [90, 80, 68, 84]
}

df = pd.DataFrame(data5)

df1 = df.drop('Java Marks', axis=1)
df2 = df.drop(1)

print(df1)
df2
# Out:
#      Name  DSA Marks  Python Marks
# 0   Tamim         50            86
# 1  Shajid         65            92
# 2  Mannan         60            48
# 3    Emon         85            75
#      Name  DSA Marks  Python Marks  Java Marks
# 0   Tamim         50            86          90
# 2  Mannan         60            48          68
# 3    Emon         85            75          84

# %% [markdown]
# ##### Create a DataFrame of employees with columns "Name", "Department", and "Salary". Sort it by "Salary" in ascending order and by "Name" in descending order.

# %%
data6 = {
    
    'Name': ['Abdul','Mannan','Tamim',"Shajid"],
    'Departmnet': ['CST','ET','ATC','Civil'],
    'Salary': [50000,80000,60000,40000]
}

df = pd.DataFrame(data6)
ascn = df.sort_values(['Salary'], ascending=True)
desen = df.sort_values(['Name'], ascending=False)
print(ascn)
print(desen)
# Out:
#      Name Departmnet  Salary
# 3  Shajid      Civil   40000
# 0   Abdul        CST   50000
# 2   Tamim        ATC   60000
# 1  Mannan         ET   80000
#      Name Departmnet  Salary
# 2   Tamim        ATC   60000
# 3  Shajid      Civil   40000
# 1  Mannan         ET   80000
# 0   Abdul        CST   50000

# %% [markdown]
# ##### Create a DataFrame of 8 students with columns "Name" and "Score". Filter and print students with Score > 60 and those with Score < 40.

# %%
data7 = {
    'Name': ['Tamim','Shajid','Emon','Nafis','Mannan','Mamun','Sha paran','Rhihan'],
    'Score': [60, 50, 30, 40, 80, 90, 20, 50]
}
df = pd.DataFrame(data7)

print(df[df['Score'] > 60])
print(df[df['Score'] < 40])
# Out:
#      Name  Score
# 4  Mannan     80
# 5   Mamun     90
#         Name  Score
# 2       Emon     30
# 6  Sha paran     20

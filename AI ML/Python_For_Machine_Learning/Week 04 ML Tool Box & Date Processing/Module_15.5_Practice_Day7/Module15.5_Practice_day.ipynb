# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Add New Column and Save File
# You have a DataFrame with column Price.
#  Create a new column Discounted_Price with (10% discounted price).
#  Save the modified DataFrame as discounted_products.csv.

# %%
df = pd.read_csv('Practice Day.csv')
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80

# %%
df['Discounted_Price'] = df['Price'] * 0.9

df.to_csv('discounted_products.csv', index=False)
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 3            1080.0
# 4            2250.0

# %%
df = pd.read_csv('Practice Day.csv')
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80

# %% [markdown]
# ### 2. Check Duplicates and Remove Them
#
# Column: EmployeeID
#  Tasks:
# Count duplicate entries
#
#
# Remove duplicates
#
#
# Display cleaned DataFrame

# %%
duplicate = df['EmployeeID'].duplicated().sum()
print(duplicate)
# Out:
# 2

# %%
Remove_duplicates = df.drop_duplicates(subset=['EmployeeID'])

# %%
Remove_duplicates
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94

# %% [markdown]
# ### 3. Handle Missing Values
# Columns: Age, Salary
#  Tasks:
# Count missing values
#
#
# Fill missing Age with mean age
#
#
# Drop rows where Salary is missing

# %%
missing_val = df[['Age', 'Salary']].isnull().sum()
print(missing_val)
# Out:
# Age       1
# Salary    2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df['Age'])
# Out:
# 0     25.0
# 1     30.0
# 2     22.0
# 3     25.0
# 4     45.0
# 5     29.0
# 6     30.4
# 7     34.0
# 8     38.0
# 9     26.0
# 10    30.0
# Name: Age, dtype: float64

# %%
df_clean = df.dropna(subset=['Salary'])
df_clean
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80

# %% [markdown]
# ### 4. Apply Statistical Functions
# Columns: Marks1, Marks2, Marks3
#  Tasks:
# Calculate mean, max for each subject
#
#
# Compute total marks per student
#
#
# Find standard deviation of total marks

# %%
df[['Marks1','Marks2','Marks3']].mean()
# Out:
# Marks1    84.727273
# Marks2    86.818182
# Marks3    86.363636
# dtype: float64

# %%
df['Total'] = df[['Marks1','Marks2','Marks3']].sum(axis=1)
print(df['Total'])
# Out:
# 0     263
# 1     240
# 2     277
# 3     263
# 4     262
# 5     236
# 6     273
# 7     244
# 8     258
# 9     281
# 10    240
# Name: Total, dtype: int64

# %%
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Total
# 0     263
# 1     240
# 2     277
# 3     263
# 4     262
# 5     236
# 6     273
# 7     244
# 8     258
# 9     281
# 10    240

# %%
df['Total'].std()
# Out:
# 15.8395362650208

# %% [markdown]
# ### 5. Histogram, Bar, Scatter, Pie
#
# Create:
#
# Histogram of Age
#
# Scatter plot (Age vs Salary)
#
# Scatter plot ( Price vs Discounted Price)

# %%
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Check')
plt.hist(df['Age'],color='Red', edgecolor='black')
plt.show()

# %%
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age and Salary')
plt.scatter(df['Age'], df['Salary'], color='Red', edgecolor='black')
plt.show()

# %%
df = pd.read_csv('discounted_products.csv')

# %%
plt.xlabel('Price')
plt.ylabel('Discounted_Price')
plt.title('Price vs Discounted Pricey')
plt.scatter(df['Price'], df['Discounted_Price'])
plt.show()

# %% [markdown]
# ### 6. Dataset : Python-for-ML/student_IQdata.csv at main · phitronio/Python-for-ML
#
#
# Load the dataset from the URL into a pandas DataFrame.
#
# Create a scatter plot with Study_Hours on the X-axis and IQ on the Y-axis.
#
# Create a scatter plot with Shoe_Size on the X-Axis and Study_Hours on the Y-axis.
#
# Create a histogram of Shoe_Size
#
# Add a title and axis labels to make the plot clear.
#
# After you plot it, answer the question: Does there appear to be a correlation?

# %%
df = pd.read_csv('student_IQdata.csv')
df
# Out:
#     Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0        13.5         2.0            17.7        72
# 1         8.0        18.0             5.0        75
# 2         6.4         7.2            22.7        78
# 3         6.9         8.7             6.6       110
# 4        10.5         8.6             5.8       104
# 5         6.8         4.8            18.1        76
# 6         5.5         7.9            24.3        80
# 7         9.6        12.6            15.7       109
# 8         9.1         5.6            24.3        73
# 9         6.7        14.6            13.1       110
# 10        9.7        14.2            20.9        98
# 11       10.4        13.7            14.0       109
# 12        7.7        11.9            23.2        95
# 13       12.5         8.3            13.3        95
# 14        7.6         9.4            16.8        95
# 15       11.4         4.6             7.9        96
# 16        5.6        12.2            12.9       107
# 17        8.4        12.3            24.3        87
# 18       12.1         6.4            17.3        77
# 19        6.4         2.7            23.2        70
# 20       13.7         5.4            20.6        78
# 21       13.6         5.3            10.0        87
# 22       18.0        10.0            15.0        98
# 23        6.3         2.2            22.8        70
# 24       11.6         2.4             5.1        90
# 25        5.4         4.9             7.7        89
# 26        9.5         2.0            35.0       145
# 27       10.4        10.6            25.4        86
# 28       13.7        14.8            27.7        88
# 29        8.3         1.6            19.0        70
# 30        6.5         3.0            20.9        70
# 31        5.2        10.3            26.6        86
# 32        7.6         3.7            24.0        70
# 33        8.9        13.5            27.2        77
# 34       10.5        13.9             8.0       116
# 35       12.8         1.5             6.9        93
# 36        6.6         3.6            12.8        84
# 37       10.3         6.0             5.6       102

# %%
plt.xlabel('Study Hours')
plt.ylabel('IQ Score')
plt.title('Study Hour and IQ Score Check')
plt.scatter(df['Study_Hour'], df['IQ_Score'])
plt.show()

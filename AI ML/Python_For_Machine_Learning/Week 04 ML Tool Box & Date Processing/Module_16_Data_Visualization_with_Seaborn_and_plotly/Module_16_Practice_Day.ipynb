# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
student = pd.read_csv('student_IQdata.csv')
student.head()
# Out:
#    Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0       13.5         2.0            17.7        72
# 1        8.0        18.0             5.0        75
# 2        6.4         7.2            22.7        78
# 3        6.9         8.7             6.6       110
# 4       10.5         8.6             5.8       104

# %%
sns.scatterplot(data = student, x = 'Study_Hour', y = 'IQ_Score')
# Out:
# <Axes: xlabel='Study_Hour', ylabel='IQ_Score'>

# %%
sns.scatterplot(data = student, x = 'Shoe_Size', y = 'Study_Hour')
# Out:
# <Axes: xlabel='Shoe_Size', ylabel='Study_Hour'>

# %%
fig = px.histogram(student, x = 'Shoe_Size')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fig = px.histogram(student, x = 'Shoe_Size')
#       2 fig.show()
#
# NameError: name 'student' is not defined

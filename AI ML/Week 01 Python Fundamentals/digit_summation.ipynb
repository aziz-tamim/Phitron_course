# %%
inp = input()
numbers = inp.split()
x = int(numbers[0]) # 13
y = int(numbers[1]) # 12
print(type(x),type(y))

last_digit_x = x%10
last_digit_y = y%10

sum = last_digit_x + last_digit_y
print(sum)
# Out:
# <class 'int'> <class 'int'>
# 5

# %%
phone_number = 456249
print(phone_number)
# Out:
# 456249

# %%
name = "Phitron"
print(name)
# Out:
# Phitron

# %%
age = 20
height = 5.6
name = "Tamim"
is_passed = True

print(type(age), type(height), type(name), type(is_passed))
age = 20.5
print(type(age))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# <class 'float'>
